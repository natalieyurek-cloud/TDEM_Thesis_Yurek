# %% [markdown]
# ## Full Modeling Setup for Analytical Forward Modeling Process and Cluster Comparison

# %% [markdown]
# imports

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import itertools
from simpeg import maps
from simpeg.electromagnetics import time_domain as tdem
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, fcluster, linkage
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# User Inputs

# %%
### Set run mode of ensemble
run_mode = "texture_excel" ### options: known_soils, parameter_range, texture_excel

### set soil type parameter options for "truth" forward model
truth_soil_type = "custom"  ### options: custom, sand, loamy sand, sandy loam, loam, silt, silt loam, clay

# %% [markdown]
# ### 1. Define Variables

# %% [markdown]
# #### 1.1 Soil Column and Timestamps

# %%
z = np.linspace(1, 2000, 300)  # cm, positive downward (20m soil column)
times = [1, 4, 12, 24, 48]   # hr

# %% [markdown]
# #### 1.2 ROSETTA/vG style soil parameter library

# %%
### Custom option for "Truth" ensemble 
custom_vg_params = {
    "custom": {
    "theta_r": 0.05,
    "theta_s": 0.4,
    "alpha": 0.1,
    "n": 2.0,
    "Ks": 10.0,
    "l": 0.5
}}
### OR preset values for sand, loamy sand, sandy loam, loam, silt, silt loam, clay

known_soils = {
    "sand": {
        "theta_r": 0.045,
        "theta_s": 0.43,
        "alpha": 0.145,
        "vg_n": 2.68,
        "Ks": 29.7,
    },
    "loamy_sand": {
        "theta_r": 0.057,
        "theta_s": 0.41,
        "alpha": 0.124,
        "vg_n": 2.28,
        "Ks": 14.6,
    },
    "sandy_loam": {
        "theta_r": 0.065,
        "theta_s": 0.41,
        "alpha": 0.075,
        "vg_n": 1.89,
        "Ks": 4.42,
    },
    "loam": {
        "theta_r": 0.078,
        "theta_s": 0.43,
        "alpha": 0.036,
        "vg_n": 1.56,
        "Ks": 1.04,
    },
    "silt": {
        "theta_r": 0.085,
        "theta_s": 0.45,
        "alpha": 0.025,
        "vg_n": 1.35,
        "Ks": 0.52,
    },
    "silty_loam": {
        "theta_r": 0.09,
        "theta_s": 0.46,
        "alpha": 0.02,
        "vg_n": 1.25,
        "Ks": 0.35,
    }, 
    "clay": {
        "theta_r": 0.1,
        "theta_s": 0.47,
        "alpha": 0.015,
        "vg_n": 1.15,
        "Ks": 0.2,
    }      
}

# %% [markdown]
# ### 2. Analytical Solution Brooks-Corey

# %% [markdown]
# #### 2.1 Conversion Functions

# %%
def vg_m(vg_n):
    """
    van Genuchten m parameter.
    """
    return 1 - (1 / vg_n)

def kr_vg_mualem(Se, vg_n, l=0.5):
    """
    van Genuchten-Mualem relative hydraulic conductivity.

    Se : effective saturation, between 0 and 1
    vg_n : van Genuchten n
    l : pore-connectivity/tortuosity parameter, commonly 0.5
    """
    Se = np.asarray(Se, dtype=float)
    Se = np.clip(Se, 1e-8, 1.0)

    m = vg_m(vg_n)

    Kr = Se**l * (1 - (1 - Se**(1 / m))**m)**2

    return Kr

# %% [markdown]
# ### 2.2 Fitted Brooks-Corey Exponent for each soil type

# %%
def fit_n_sisson_to_vg_mualem(vg_n, Se_min=0.1, Se_max=0.95, l=0.5):
    """
    Fit the Sisson/Brooks-Corey exponent n_sisson so that
    Kr = Se^(1/n_sisson) approximates the van Genuchten-Mualem curve.
    """

    Se = np.linspace(Se_min, Se_max, 300)
    Kr_vg = kr_vg_mualem(Se, vg_n=vg_n, l=l)

    # Avoid log of zero
    valid = (Kr_vg > 0) & (Se > 0)

    x = np.log(Se[valid])
    y = np.log(Kr_vg[valid])

    # Force fit through origin because log(Kr) = slope * log(Se)
    slope = np.sum(x * y) / np.sum(x * x)

    n_fit = 1 / slope

    return n_fit

# %%
for soil_name, item in known_soils.items():
    known_soils[soil_name]["bc_n_fitted"] = fit_n_sisson_to_vg_mualem(
        known_soils[soil_name]["vg_n"],
        Se_min=0.1,
        Se_max=0.95,
        l=0.5
    )

# %% [markdown]
# #### 2.3 Run Analytical Solution

# %%
def theta_brooks_corey_sisson_piecewise(
        z, t, theta_r, theta_s, Ks, bc_n, q0,
        return_star_mid=False,
        debug=False):

    z = np.asarray(z, dtype=float)

    if t <= 0:
        return np.full_like(z, theta_s)

    # Transformed depth for saturated initial condition
    z_star = (Ks / q0) ** bc_n * z

    # Sisson variable: z*/t
    s_star = np.maximum(z_star / t, 1e-12)

    # Brooks-Corey derivative setup
    A = Ks / (bc_n * (theta_s - theta_r))
    exponent = 1 / ((1 / bc_n) - 1)

    # Middle transformed solution
    theta_star_mid = theta_r + (theta_s - theta_r) * (s_star / A) ** exponent

    if debug:
        print("bc_n =", bc_n)
        print("Ks =", Ks)
        print("q0 =", q0)
        print("A =", A)
        print("exponent =", exponent)
        print("z_star min =", z_star.min())
        print("z_star max =", z_star.max())
        print("s_star min =", s_star.min())
        print("s_star max =", s_star.max())
        print("theta_star_mid min =", theta_star_mid.min())
        print("theta_star_mid max =", theta_star_mid.max())

    if return_star_mid:
        return theta_star_mid

    # Piecewise solution based on Sisson Eq. 15

    theta_star = np.clip(theta_star_mid, theta_r, theta_s)

    return theta_star

# %% [markdown]
# ### 3. Ensemble

# %% [markdown]
# #### 3.1 Process a large number of texture cases

# %%
### I think this is a test block and can be removed
"""texture_excel_path = Path("C:/Users/natal/OneDrive/Desktop/26' HYDROGEO/Project [THESIS]/soils_texture_data_20191028.xlsx")

print("File exists:", texture_excel_path.exists())

xl = pd.ExcelFile(texture_excel_path)
print("Sheet names:", xl.sheet_names)

texture_df = pd.read_excel(texture_excel_path, sheet_name="soil texture data")

print(texture_df.head())
print(texture_df.columns)
print(texture_df.shape)"""
# Out:
# 'texture_excel_path = Path("C:/Users/natal/OneDrive/Desktop/26\' HYDROGEO/Project [THESIS]/soils_texture_data_20191028.xlsx")\n\nprint("File exists:", texture_excel_path.exists())\n\nxl = pd.ExcelFile(texture_excel_path)\nprint("Sheet names:", xl.sheet_names)\n\ntexture_df = pd.read_excel(texture_excel_path, sheet_name="soil texture data")\n\nprint(texture_df.head())\nprint(texture_df.columns)\nprint(texture_df.shape)'

# %%
texture_excel_path = Path("C:/Users/natal/OneDrive/Desktop/26' HYDROGEO/Project [THESIS]/soils_texture_data_20191028.xlsx")

texture_df = pd.read_excel(texture_excel_path, sheet_name="soil texture data")

texture_step = 4  # options from current 2% sheet: 10 (66), 4 (351), or 2 (1326)

texture_df_subset = texture_df[
    (texture_df["sand"] % texture_step == 0) &
    (texture_df["silt"] % texture_step == 0) &
    (texture_df["clay"] % texture_step == 0)
].copy()

print(f"Using {len(texture_df_subset)} texture cases")

texture_excel_scenarios = {}

for row_id, row in texture_df_subset.iterrows():

    scenario_name = (
        f"sand{int(row['sand']):03d}_"
        f"silt{int(row['silt']):03d}_"
        f"clay{int(row['clay']):03d}"
    )

    vg_n = row["n"]
    Ks_cm_hr = row["Ks (cm/day)"] / 24

    texture_excel_scenarios[scenario_name] = {
        "base_soil": row["USDA Class"],
        "sand": row["sand"],
        "silt": row["silt"],
        "clay": row["clay"],
        "USDA_class": row["USDA Class"],
        "theta_r": row["thr"],
        "theta_s": row["ths"],
        "alpha": row["Alfa (1/cm)"],
        "vg_n": vg_n,
        "Ks": Ks_cm_hr,
        "bc_n": fit_n_sisson_to_vg_mualem(vg_n),
        "q0": Ks_cm_hr
    }

print(f"Built {len(texture_excel_scenarios)} texture scenarios")
# Out:
# Using 351 texture cases
# Built 351 texture scenarios

# %% [markdown]
# #### 3.2 Select Run mode

# %% [markdown]
# "known soils" used for model testing only
# Simplify and remove at a later date for final model version *7/2/26

# %%
if run_mode == "known_soils":

    scenarios_to_run = {
        soil_name: {
            "base_soil": soil_name,
            "theta_r": soil["theta_r"],
            "theta_s": soil["theta_s"],
            "alpha": soil["alpha"],
            "vg_n": soil["vg_n"],
            "Ks": soil["Ks"],
            "l": soil.get("l", 0.5),
            "bc_n": soil["bc_n_fitted"],
            "q0": soil["Ks"]
        }
        for soil_name, soil in known_soils.items()
    }

elif run_mode == "texture_excel":

    scenarios_to_run = texture_excel_scenarios.copy()

else:
    raise ValueError(
        "run_mode must be 'known_soils', 'parameter_range', or 'texture_excel'"
    )

# %% [markdown]
# #### 3.3 Build Ensemble
# ##### loop through each soil case

# %%
theta_results = {}
results = []

for scenario_name, params in scenarios_to_run.items():

    print(
        f"Running {scenario_name}: "
        f"Ks={params['Ks']:.4f}, bc_n={params['bc_n']:.4f}"
    )

    theta_results[scenario_name] = {}

    for t in times:
        theta = theta_brooks_corey_sisson_piecewise(
            z=z,
            t=t,
            theta_r=params["theta_r"],
            theta_s=params["theta_s"],
            Ks=params["Ks"],
            bc_n=params["bc_n"],
            q0=params["q0"],
            debug=False
        )

        theta_results[scenario_name][t] = theta

    results.append({
        "scenario": scenario_name,
        "base_soil": params.get("base_soil", np.nan),
        "USDA_class": params.get("USDA_class", params.get("base_soil", np.nan)),
        "sand": params.get("sand", np.nan),
        "silt": params.get("silt", np.nan),
        "clay": params.get("clay", np.nan),
        "theta_r": params["theta_r"],
        "theta_s": params["theta_s"],
        "alpha": params.get("alpha", np.nan),
        "vg_n": params.get("vg_n", np.nan),
        "bc_n": params["bc_n"],
        "Ks": params["Ks"],
        "q0": params["q0"]
    })
    
results_df = pd.DataFrame(results)
results_df.to_csv("analytical_ensemble_summary.csv", index=False)
# Out:
# Running sand000_silt000_clay100: Ks=0.7704, bc_n=0.0534
# Running sand000_silt004_clay096: Ks=0.7487, bc_n=0.0527
# Running sand000_silt008_clay092: Ks=0.7417, bc_n=0.0533
# Running sand000_silt012_clay088: Ks=0.7379, bc_n=0.0549
# Running sand000_silt016_clay084: Ks=0.7308, bc_n=0.0572
# Running sand000_silt020_clay080: Ks=0.7129, bc_n=0.0600
# Running sand000_silt024_clay076: Ks=0.7021, bc_n=0.0631
# Running sand000_silt028_clay072: Ks=0.7558, bc_n=0.0668
# Running sand000_silt032_clay068: Ks=0.9683, bc_n=0.0709
# Running sand000_silt036_clay064: Ks=1.1700, bc_n=0.0755
# Running sand000_silt040_clay060: Ks=1.0654, bc_n=0.0805
# Running sand000_silt044_clay056: Ks=0.8279, bc_n=0.0860
# Running sand000_silt048_clay052: Ks=0.6658, bc_n=0.0922
# Running sand000_silt052_clay048: Ks=0.5617, bc_n=0.0988
# Running sand000_silt056_clay044: Ks=0.4896, bc_n=0.1055
# Running sand000_silt060_clay040: Ks=0.4321, bc_n=0.1117
# Running sand000_silt064_clay036: Ks=0.3817, bc_n=0.1173
# Running sand000_silt068_clay032: Ks=0.3525, bc_n=0.1225
# Running sand000_silt072_clay028: Ks=0.3346, bc_n=0.1269
# Running sand000_silt076_clay024: Ks=0.3375, bc_n=0.1306
# Running sand000_silt080_clay020: Ks=0.3779, bc_n=0.1336
# Running sand000_silt084_clay016: Ks=0.4679, bc_n=0.1359
# Running sand000_silt088_clay012: Ks=0.6154, bc_n=0.1376
# Running sand000_silt092_clay008: Ks=0.8317, bc_n=0.1386
# Running sand000_silt096_clay004: Ks=1.1450, bc_n=0.1386
# Running sand000_silt100_clay000: Ks=1.5842, bc_n=0.1376
# Running sand004_silt000_clay096: Ks=0.7633, bc_n=0.0518
# Running sand004_silt004_clay092: Ks=0.7487, bc_n=0.0516
# Running sand004_silt008_clay088: Ks=0.7379, bc_n=0.0528
# Running sand004_silt012_clay084: Ks=0.7379, bc_n=0.0549
# Running sand004_silt016_clay080: Ks=0.7417, bc_n=0.0577
# Running sand004_silt020_clay076: Ks=0.7450, bc_n=0.0608
# Running sand004_silt024_clay072: Ks=0.7596, bc_n=0.0644
# Running sand004_silt028_clay068: Ks=0.8642, bc_n=0.0685
# Running sand004_silt032_clay064: Ks=1.1196, bc_n=0.0731
# Running sand004_silt036_clay060: Ks=1.2421, bc_n=0.0783
# Running sand004_silt040_clay056: Ks=0.9829, bc_n=0.0840
# Running sand004_silt044_clay052: Ks=0.7704, bc_n=0.0903
# Running sand004_silt048_clay048: Ks=0.6446, bc_n=0.0972
# Running sand004_silt052_clay044: Ks=0.5617, bc_n=0.1043
# Running sand004_silt056_clay040: Ks=0.5075, bc_n=0.1112
# Running sand004_silt060_clay036: Ks=0.4608, bc_n=0.1175
# Running sand004_silt064_clay032: Ks=0.4321, bc_n=0.1232
# Running sand004_silt068_clay028: Ks=0.4250, bc_n=0.1284
# Running sand004_silt072_clay024: Ks=0.4392, bc_n=0.1327
# Running sand004_silt076_clay020: Ks=0.5075, bc_n=0.1361
# Running sand004_silt080_clay016: Ks=0.6550, bc_n=0.1387
# Running sand004_silt084_clay012: Ks=0.8963, bc_n=0.1404
# Running sand004_silt088_clay008: Ks=1.2454, bc_n=0.1413
# Running sand004_silt092_clay004: Ks=1.7425, bc_n=0.1411
# Running sand004_silt096_clay000: Ks=2.4696, bc_n=0.1397
# Running sand008_silt000_clay092: Ks=0.7379, bc_n=0.0502
# Running sand008_silt004_clay088: Ks=0.7346, bc_n=0.0507
# Running sand008_silt008_clay084: Ks=0.7238, bc_n=0.0525
# Running sand008_silt012_clay080: Ks=0.7200, bc_n=0.0552
# Running sand008_silt016_clay076: Ks=0.7308, bc_n=0.0583
# Running sand008_silt020_clay072: Ks=0.7525, bc_n=0.0618
# Running sand008_silt024_clay068: Ks=0.8063, bc_n=0.0659
# Running sand008_silt028_clay064: Ks=0.9542, bc_n=0.0705
# Running sand008_silt032_clay060: Ks=1.1521, bc_n=0.0756
# Running sand008_silt036_clay056: Ks=1.1087, bc_n=0.0815
# Running sand008_silt040_clay052: Ks=0.8425, bc_n=0.0880
# Running sand008_silt044_clay048: Ks=0.6913, bc_n=0.0951
# Running sand008_silt048_clay044: Ks=0.5975, bc_n=0.1027
# Running sand008_silt052_clay040: Ks=0.5471, bc_n=0.1101
# Running sand008_silt056_clay036: Ks=0.5075, bc_n=0.1171
# Running sand008_silt060_clay032: Ks=0.4788, bc_n=0.1235
# Running sand008_silt064_clay028: Ks=0.4750, bc_n=0.1293
# Running sand008_silt068_clay024: Ks=0.4933, bc_n=0.1344
# Running sand008_silt072_clay020: Ks=0.5725, bc_n=0.1384
# Running sand008_silt076_clay016: Ks=0.7450, bc_n=0.1413
# Running sand008_silt080_clay012: Ks=1.0296, bc_n=0.1432
# Running sand008_silt084_clay008: Ks=1.4579, bc_n=0.1440
# Running sand008_silt088_clay004: Ks=2.0737, bc_n=0.1436
# Running sand008_silt092_clay000: Ks=2.9771, bc_n=0.1419
# Running sand012_silt000_clay088: Ks=0.6983, bc_n=0.0489
# Running sand012_silt004_clay084: Ks=0.6983, bc_n=0.0501
# Running sand012_silt008_clay080: Ks=0.6950, bc_n=0.0525
# Running sand012_silt012_clay076: Ks=0.6913, bc_n=0.0555
# Running sand012_silt016_clay072: Ks=0.7054, bc_n=0.0590
# Running sand012_silt020_clay068: Ks=0.7487, bc_n=0.0630
# Running sand012_silt024_clay064: Ks=0.8425, bc_n=0.0676
# Running sand012_silt028_clay060: Ks=0.9754, bc_n=0.0728
# Running sand012_silt032_clay056: Ks=1.0117, bc_n=0.0786
# Running sand012_silt036_clay052: Ks=0.8712, bc_n=0.0852
# Running sand012_silt040_clay048: Ks=0.7129, bc_n=0.0925
# Running sand012_silt044_clay044: Ks=0.6083, bc_n=0.1004
# Running sand012_silt048_clay040: Ks=0.5579, bc_n=0.1084
# Running sand012_silt052_clay036: Ks=0.5254, bc_n=0.1160
# Running sand012_silt056_clay032: Ks=0.5042, bc_n=0.1230
# Running sand012_silt060_clay028: Ks=0.5004, bc_n=0.1295
# Running sand012_silt064_clay024: Ks=0.5221, bc_n=0.1353
# Running sand012_silt068_clay020: Ks=0.6050, bc_n=0.1401
# Running sand012_silt072_clay016: Ks=0.7850, bc_n=0.1436
# Running sand012_silt076_clay012: Ks=1.1050, bc_n=0.1458
# Running sand012_silt080_clay008: Ks=1.6021, bc_n=0.1467
# Running sand012_silt084_clay004: Ks=2.3292, bc_n=0.1461
# Running sand012_silt088_clay000: Ks=3.3842, bc_n=0.1441
# Running sand016_silt000_clay084: Ks=0.6408, bc_n=0.0480
# Running sand016_silt004_clay080: Ks=0.6479, bc_n=0.0498
# Running sand016_silt008_clay076: Ks=0.6517, bc_n=0.0526
# Running sand016_silt012_clay072: Ks=0.6588, bc_n=0.0560
# Running sand016_silt016_clay068: Ks=0.6842, bc_n=0.0600
# Running sand016_silt020_clay064: Ks=0.7450, bc_n=0.0645
# Running sand016_silt024_clay060: Ks=0.8496, bc_n=0.0696
# Running sand016_silt028_clay056: Ks=0.8963, bc_n=0.0754
# Running sand016_silt032_clay052: Ks=0.7667, bc_n=0.0820
# Running sand016_silt036_clay048: Ks=0.6658, bc_n=0.0893
# Running sand016_silt040_clay044: Ks=0.6012, bc_n=0.0974
# Running sand016_silt044_clay040: Ks=0.5471, bc_n=0.1059
# Running sand016_silt048_clay036: Ks=0.5254, bc_n=0.1142
# Running sand016_silt052_clay032: Ks=0.5112, bc_n=0.1218
# Running sand016_silt056_clay028: Ks=0.5112, bc_n=0.1289
# Running sand016_silt060_clay024: Ks=0.5363, bc_n=0.1353
# Running sand016_silt064_clay020: Ks=0.6154, bc_n=0.1409
# Running sand016_silt068_clay016: Ks=0.8029, bc_n=0.1451
# Running sand016_silt072_clay012: Ks=1.1483, bc_n=0.1478
# Running sand016_silt076_clay008: Ks=1.7171, bc_n=0.1489
# Running sand016_silt080_clay004: Ks=2.5633, bc_n=0.1484
# Running sand016_silt084_clay000: Ks=3.7800, bc_n=0.1461
# Running sand020_silt000_clay080: Ks=0.5687, bc_n=0.0474
# Running sand020_silt004_clay076: Ks=0.5796, bc_n=0.0497
# Running sand020_silt008_clay072: Ks=0.5975, bc_n=0.0529
# Running sand020_silt012_clay068: Ks=0.6229, bc_n=0.0567
# Running sand020_silt016_clay064: Ks=0.6625, bc_n=0.0611
# Running sand020_silt020_clay060: Ks=0.7379, bc_n=0.0662
# Running sand020_silt024_clay056: Ks=0.8100, bc_n=0.0720
# Running sand020_silt028_clay052: Ks=0.7238, bc_n=0.0785
# Running sand020_silt032_clay048: Ks=0.5438, bc_n=0.0858
# Running sand020_silt036_clay044: Ks=0.5183, bc_n=0.0939
# Running sand020_silt040_clay040: Ks=0.5221, bc_n=0.1026
# Running sand020_silt044_clay036: Ks=0.5112, bc_n=0.1114
# Running sand020_silt048_clay032: Ks=0.5112, bc_n=0.1197
# Running sand020_silt052_clay028: Ks=0.5183, bc_n=0.1273
# Running sand020_silt056_clay024: Ks=0.5438, bc_n=0.1343
# Running sand020_silt060_clay020: Ks=0.6262, bc_n=0.1405
# Running sand020_silt064_clay016: Ks=0.8208, bc_n=0.1455
# Running sand020_silt068_clay012: Ks=1.1950, bc_n=0.1489
# Running sand020_silt072_clay008: Ks=1.8250, bc_n=0.1504
# Running sand020_silt076_clay004: Ks=2.7971, bc_n=0.1500
# Running sand020_silt080_clay000: Ks=4.2121, bc_n=0.1476
# Running sand024_silt000_clay076: Ks=0.4933, bc_n=0.0471
# Running sand024_silt004_clay072: Ks=0.5075, bc_n=0.0499
# Running sand024_silt008_clay068: Ks=0.5329, bc_n=0.0535
# Running sand024_silt012_clay064: Ks=0.5725, bc_n=0.0577
# Running sand024_silt016_clay060: Ks=0.6338, bc_n=0.0626
# Running sand024_silt020_clay056: Ks=0.7054, bc_n=0.0683
# Running sand024_silt024_clay052: Ks=0.6950, bc_n=0.0747
# Running sand024_silt028_clay048: Ks=0.5221, bc_n=0.0820
# Running sand024_silt032_clay044: Ks=0.4067, bc_n=0.0899
# Running sand024_silt036_clay040: Ks=0.4175, bc_n=0.0986
# Running sand024_silt040_clay036: Ks=0.4788, bc_n=0.1077
# Running sand024_silt044_clay032: Ks=0.5042, bc_n=0.1165
# Running sand024_silt048_clay028: Ks=0.5221, bc_n=0.1247
# Running sand024_silt052_clay024: Ks=0.5617, bc_n=0.1322
# Running sand024_silt056_clay020: Ks=0.6479, bc_n=0.1389
# Running sand024_silt060_clay016: Ks=0.8496, bc_n=0.1446
# Running sand024_silt064_clay012: Ks=1.2492, bc_n=0.1487
# Running sand024_silt068_clay008: Ks=1.9333, bc_n=0.1508
# Running sand024_silt072_clay004: Ks=3.0167, bc_n=0.1507
# Running sand024_silt076_clay000: Ks=4.6079, bc_n=0.1483
# Running sand028_silt000_clay072: Ks=0.4500, bc_n=0.0473
# Running sand028_silt004_clay068: Ks=0.4571, bc_n=0.0504
# Running sand028_silt008_clay064: Ks=0.4750, bc_n=0.0544
# Running sand028_silt012_clay060: Ks=0.5183, bc_n=0.0591
# Running sand028_silt016_clay056: Ks=0.5833, bc_n=0.0645
# Running sand028_silt020_clay052: Ks=0.6154, bc_n=0.0708
# Running sand028_silt024_clay048: Ks=0.5150, bc_n=0.0779
# Running sand028_silt028_clay044: Ks=0.3708, bc_n=0.0857
# Running sand028_silt032_clay040: Ks=0.3242, bc_n=0.0943
# Running sand028_silt036_clay036: Ks=0.3538, bc_n=0.1033
# Running sand028_silt040_clay032: Ks=0.4538, bc_n=0.1124
# Running sand028_silt044_clay028: Ks=0.5150, bc_n=0.1211
# Running sand028_silt048_clay024: Ks=0.5687, bc_n=0.1289
# Running sand028_silt052_clay020: Ks=0.6658, bc_n=0.1360
# Running sand028_silt056_clay016: Ks=0.8783, bc_n=0.1421
# Running sand028_silt060_clay012: Ks=1.2996, bc_n=0.1469
# Running sand028_silt064_clay008: Ks=2.0450, bc_n=0.1497
# Running sand028_silt068_clay004: Ks=3.2471, bc_n=0.1501
# Running sand028_silt072_clay000: Ks=5.0400, bc_n=0.1480
# Running sand032_silt000_clay068: Ks=0.4679, bc_n=0.0478
# Running sand032_silt004_clay064: Ks=0.4608, bc_n=0.0513
# Running sand032_silt008_clay060: Ks=0.4646, bc_n=0.0557
# Running sand032_silt012_clay056: Ks=0.4896, bc_n=0.0608
# Running sand032_silt016_clay052: Ks=0.5112, bc_n=0.0668
# Running sand032_silt020_clay048: Ks=0.4646, bc_n=0.0737
# Running sand032_silt024_clay044: Ks=0.3350, bc_n=0.0813
# Running sand032_silt028_clay040: Ks=0.2658, bc_n=0.0897
# Running sand032_silt032_clay036: Ks=0.2679, bc_n=0.0986
# Running sand032_silt036_clay032: Ks=0.3167, bc_n=0.1077
# Running sand032_silt040_clay028: Ks=0.4392, bc_n=0.1164
# Running sand032_silt044_clay024: Ks=0.5471, bc_n=0.1246
# Running sand032_silt048_clay020: Ks=0.6625, bc_n=0.1318
# Running sand032_silt052_clay016: Ks=0.8892, bc_n=0.1382
# Running sand032_silt056_clay012: Ks=1.3392, bc_n=0.1434
# Running sand032_silt060_clay008: Ks=2.1421, bc_n=0.1467
# Running sand032_silt064_clay004: Ks=3.4742, bc_n=0.1478
# Running sand032_silt068_clay000: Ks=5.5079, bc_n=0.1462
# Running sand036_silt000_clay064: Ks=0.5329, bc_n=0.0487
# Running sand036_silt004_clay060: Ks=0.5221, bc_n=0.0526
# Running sand036_silt008_clay056: Ks=0.5183, bc_n=0.0574
# Running sand036_silt012_clay052: Ks=0.5150, bc_n=0.0631
# Running sand036_silt016_clay048: Ks=0.4679, bc_n=0.0696
# Running sand036_silt020_clay044: Ks=0.3404, bc_n=0.0770
# Running sand036_silt024_clay040: Ks=0.2371, bc_n=0.0850
# Running sand036_silt028_clay036: Ks=0.2137, bc_n=0.0936
# Running sand036_silt032_clay032: Ks=0.2350, bc_n=0.1025
# Running sand036_silt036_clay028: Ks=0.2917, bc_n=0.1112
# Running sand036_silt040_clay024: Ks=0.4142, bc_n=0.1193
# Running sand036_silt044_clay020: Ks=0.5904, bc_n=0.1266
# Running sand036_silt048_clay016: Ks=0.8317, bc_n=0.1330
# Running sand036_silt052_clay012: Ks=1.2996, bc_n=0.1383
# Running sand036_silt056_clay008: Ks=2.1529, bc_n=0.1420
# Running sand036_silt060_clay004: Ks=3.6000, bc_n=0.1436
# Running sand036_silt064_clay000: Ks=5.9042, bc_n=0.1428
# Running sand040_silt000_clay060: Ks=0.5975, bc_n=0.0502
# Running sand040_silt004_clay056: Ks=0.5904, bc_n=0.0545
# Running sand040_silt008_clay052: Ks=0.5867, bc_n=0.0598
# Running sand040_silt012_clay048: Ks=0.5546, bc_n=0.0659
# Running sand040_silt016_clay044: Ks=0.4354, bc_n=0.0728
# Running sand040_silt020_clay040: Ks=0.2875, bc_n=0.0805
# Running sand040_silt024_clay036: Ks=0.2246, bc_n=0.0887
# Running sand040_silt028_clay032: Ks=0.2262, bc_n=0.0973
# Running sand040_silt032_clay028: Ks=0.2546, bc_n=0.1058
# Running sand040_silt036_clay024: Ks=0.3046, bc_n=0.1137
# Running sand040_silt040_clay020: Ks=0.4142, bc_n=0.1207
# Running sand040_silt044_clay016: Ks=0.6479, bc_n=0.1269
# Running sand040_silt048_clay012: Ks=1.0550, bc_n=0.1321
# Running sand040_silt052_clay008: Ks=1.8542, bc_n=0.1359
# Running sand040_silt056_clay004: Ks=3.3300, bc_n=0.1379
# Running sand040_silt060_clay000: Ks=5.8321, bc_n=0.1377
# Running sand044_silt000_clay056: Ks=0.6550, bc_n=0.0522
# Running sand044_silt004_clay052: Ks=0.6517, bc_n=0.0570
# Running sand044_silt008_clay048: Ks=0.6408, bc_n=0.0626
# Running sand044_silt012_clay044: Ks=0.5546, bc_n=0.0691
# Running sand044_silt016_clay040: Ks=0.3925, bc_n=0.0763
# Running sand044_silt020_clay036: Ks=0.2812, bc_n=0.0841
# Running sand044_silt024_clay032: Ks=0.2646, bc_n=0.0923
# Running sand044_silt028_clay028: Ks=0.2950, bc_n=0.1004
# Running sand044_silt032_clay024: Ks=0.3425, bc_n=0.1080
# Running sand044_silt036_clay020: Ks=0.3996, bc_n=0.1147
# Running sand044_silt040_clay016: Ks=0.5329, bc_n=0.1204
# Running sand044_silt044_clay012: Ks=0.8604, bc_n=0.1252
# Running sand044_silt048_clay008: Ks=1.4650, bc_n=0.1288
# Running sand044_silt052_clay004: Ks=2.5992, bc_n=0.1311
# Running sand044_silt056_clay000: Ks=4.7158, bc_n=0.1315
# Running sand048_silt000_clay052: Ks=0.7092, bc_n=0.0548
# Running sand048_silt004_clay048: Ks=0.7129, bc_n=0.0599
# Running sand048_silt008_clay044: Ks=0.6658, bc_n=0.0659
# Running sand048_silt012_clay040: Ks=0.5183, bc_n=0.0726
# Running sand048_silt016_clay036: Ks=0.3708, bc_n=0.0799
# Running sand048_silt020_clay032: Ks=0.3179, bc_n=0.0877
# Running sand048_silt024_clay028: Ks=0.3496, bc_n=0.0954
# Running sand048_silt028_clay024: Ks=0.4212, bc_n=0.1027
# Running sand048_silt032_clay020: Ks=0.5075, bc_n=0.1091
# Running sand048_silt036_clay016: Ks=0.6121, bc_n=0.1143
# Running sand048_silt040_clay012: Ks=0.8350, bc_n=0.1184
# Running sand048_silt044_clay008: Ks=1.3750, bc_n=0.1216
# Running sand048_silt048_clay004: Ks=2.3546, bc_n=0.1238
# Running sand048_silt052_clay000: Ks=4.0679, bc_n=0.1248
# Running sand052_silt000_clay048: Ks=0.7633, bc_n=0.0579
# Running sand052_silt004_clay044: Ks=0.7487, bc_n=0.0633
# Running sand052_silt008_clay040: Ks=0.6408, bc_n=0.0695
# Running sand052_silt012_clay036: Ks=0.4788, bc_n=0.0764
# Running sand052_silt016_clay032: Ks=0.3887, bc_n=0.0836
# Running sand052_silt020_clay028: Ks=0.4067, bc_n=0.0910
# Running sand052_silt024_clay024: Ks=0.4896, bc_n=0.0980
# Running sand052_silt028_clay020: Ks=0.6083, bc_n=0.1041
# Running sand052_silt032_clay016: Ks=0.7633, bc_n=0.1090
# Running sand052_silt036_clay012: Ks=0.9863, bc_n=0.1125
# Running sand052_silt040_clay008: Ks=1.3896, bc_n=0.1151
# Running sand052_silt044_clay004: Ks=2.2933, bc_n=0.1170
# Running sand052_silt048_clay000: Ks=3.9242, bc_n=0.1183
# Running sand056_silt000_clay044: Ks=0.7883, bc_n=0.0614
# Running sand056_silt004_clay040: Ks=0.7271, bc_n=0.0672
# Running sand056_silt008_clay036: Ks=0.5867, bc_n=0.0735
# Running sand056_silt012_clay032: Ks=0.4750, bc_n=0.0804
# Running sand056_silt016_clay028: Ks=0.4646, bc_n=0.0874
# Running sand056_silt020_clay024: Ks=0.5546, bc_n=0.0942
# Running sand056_silt024_clay020: Ks=0.6983, bc_n=0.1001
# Running sand056_silt028_clay016: Ks=0.8892, bc_n=0.1047
# Running sand056_silt032_clay012: Ks=1.1629, bc_n=0.1080
# Running sand056_silt036_clay008: Ks=1.6092, bc_n=0.1102
# Running sand056_silt040_clay004: Ks=2.3183, bc_n=0.1117
# Running sand056_silt044_clay000: Ks=3.7442, bc_n=0.1130
# Running sand060_silt000_clay040: Ks=0.7633, bc_n=0.0655
# Running sand060_silt004_clay036: Ks=0.6588, bc_n=0.0715
# Running sand060_silt008_clay032: Ks=0.5471, bc_n=0.0780
# Running sand060_silt012_clay028: Ks=0.5221, bc_n=0.0847
# Running sand060_silt016_clay024: Ks=0.6083, bc_n=0.0913
# Running sand060_silt020_clay020: Ks=0.7812, bc_n=0.0972
# Running sand060_silt024_clay016: Ks=1.0079, bc_n=0.1019
# Running sand060_silt028_clay012: Ks=1.2996, bc_n=0.1052
# Running sand060_silt032_clay008: Ks=1.7821, bc_n=0.1072
# Running sand060_silt036_clay004: Ks=2.5667, bc_n=0.1085
# Running sand060_silt040_clay000: Ks=3.7442, bc_n=0.1099
# Running sand064_silt000_clay036: Ks=0.6875, bc_n=0.0705
# Running sand064_silt004_clay032: Ks=0.5942, bc_n=0.0767
# Running sand064_silt008_clay028: Ks=0.5650, bc_n=0.0832
# Running sand064_silt012_clay024: Ks=0.6446, bc_n=0.0898
# Running sand064_silt016_clay020: Ks=0.8533, bc_n=0.0958
# Running sand064_silt020_clay016: Ks=1.1267, bc_n=0.1007
# Running sand064_silt024_clay012: Ks=1.4363, bc_n=0.1043
# Running sand064_silt028_clay008: Ks=1.8938, bc_n=0.1066
# Running sand064_silt032_clay004: Ks=2.7000, bc_n=0.1081
# Running sand064_silt036_clay000: Ks=3.9600, bc_n=0.1098
# Running sand068_silt000_clay032: Ks=0.6192, bc_n=0.0766
# Running sand068_silt004_clay028: Ks=0.5867, bc_n=0.0831
# Running sand068_silt008_clay024: Ks=0.6658, bc_n=0.0898
# Running sand068_silt012_clay020: Ks=0.8963, bc_n=0.0962
# Running sand068_silt016_clay016: Ks=1.2421, bc_n=0.1017
# Running sand068_silt020_clay012: Ks=1.6054, bc_n=0.1059
# Running sand068_silt024_clay008: Ks=2.0304, bc_n=0.1089
# Running sand068_silt028_clay004: Ks=2.7829, bc_n=0.1110
# Running sand068_silt032_clay000: Ks=4.0321, bc_n=0.1134
# Running sand072_silt000_clay028: Ks=0.6050, bc_n=0.0849
# Running sand072_silt004_clay024: Ks=0.6804, bc_n=0.0919
# Running sand072_silt008_clay020: Ks=0.9179, bc_n=0.0989
# Running sand072_silt012_clay016: Ks=1.3608, bc_n=0.1053
# Running sand072_silt016_clay012: Ks=1.8396, bc_n=0.1106
# Running sand072_silt020_clay008: Ks=2.2679, bc_n=0.1148
# Running sand072_silt024_clay004: Ks=2.9521, bc_n=0.1182
# Running sand072_silt028_clay000: Ks=4.1400, bc_n=0.1217
# Running sand076_silt000_clay024: Ks=0.7129, bc_n=0.0966
# Running sand076_silt004_clay020: Ks=0.9613, bc_n=0.1046
# Running sand076_silt008_clay016: Ks=1.4942, bc_n=0.1124
# Running sand076_silt012_clay012: Ks=2.1963, bc_n=0.1194
# Running sand076_silt016_clay008: Ks=2.7325, bc_n=0.1255
# Running sand076_silt020_clay004: Ks=3.3696, bc_n=0.1308
# Running sand076_silt024_clay000: Ks=4.5358, bc_n=0.1360
# Running sand080_silt000_clay020: Ks=1.0729, bc_n=0.1142
# Running sand080_silt004_clay016: Ks=1.6921, bc_n=0.1239
# Running sand080_silt008_clay012: Ks=2.7325, bc_n=0.1333
# Running sand080_silt012_clay008: Ks=3.6000, bc_n=0.1419
# Running sand080_silt016_clay004: Ks=4.2842, bc_n=0.1498
# Running sand080_silt020_clay000: Ks=5.4358, bc_n=0.1573
# Running sand084_silt000_clay016: Ks=2.0846, bc_n=0.1407
# Running sand084_silt004_clay012: Ks=3.5750, bc_n=0.1531
# Running sand084_silt008_clay008: Ks=5.2558, bc_n=0.1648
# Running sand084_silt012_clay004: Ks=6.2279, bc_n=0.1755
# Running sand084_silt016_clay000: Ks=7.4521, bc_n=0.1851
# Running sand088_silt000_clay012: Ks=5.0758, bc_n=0.1781
# Running sand088_silt004_clay008: Ks=8.3521, bc_n=0.1928
# Running sand088_silt008_clay004: Ks=10.3679, bc_n=0.2058
# Running sand088_silt012_clay000: Ks=11.8800, bc_n=0.2167
# Running sand092_silt000_clay008: Ks=13.7521, bc_n=0.2219
# Running sand092_silt004_clay004: Ks=18.9000, bc_n=0.2358
# Running sand092_silt008_clay000: Ks=20.9879, bc_n=0.2468
# Running sand096_silt000_clay004: Ks=32.6879, bc_n=0.2611
# Running sand096_silt004_clay000: Ks=36.5138, bc_n=0.2715
# Running sand100_silt000_clay000: Ks=59.5204, bc_n=0.2904

# %% [markdown]
# ### 4. Plot Water Content vs Depth over Time

# %% [markdown]
# #### 4.1 Reusable water content plotting function

# %%
def plot_theta_profiles(theta_results, scenario_name, z):
    """Plot water-content profiles through drainage time."""

    plt.figure(figsize=(6, 7))

    for t, theta_profile in theta_results[scenario_name].items():

        plt.plot(
            theta_profile,
            z,
            label=f"{t} hr"
        )

    plt.gca().invert_yaxis()
    plt.xlabel("Water content, theta")
    plt.ylabel("Depth [cm]")
    plt.title(f"Analytical drainage: {scenario_name}")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### 4.2 Select a Specific Scenario for Plotting
# ##### or allow for the next iteration to plot

# %%
theta_scenario_to_plot = next(iter(theta_results))   ### = eplicit scenario or exsiting soil type 

plot_theta_profiles(
    theta_results=theta_results,
    scenario_name=theta_scenario_to_plot,
    z=z
)

# %% [markdown]
# ### 5. Conversion Using Archies Law
# #### Use Archies Law to conver water content to electrica conductivity

# %%
def theta_to_conductivity(theta, sigma_w, m_archie):
    """
    Convert volumetric water content to bulk electrical
    conductivity using simplified Archie's law.
    """
    sigma_bulk = sigma_w * theta**m_archie

    return sigma_bulk


# Archie parameters used for all scenarios
sigma_w = 0.1       # Water conductivity [S/m] - adjust as needed
m_archie = 1.5      # Cementation exponent - adjust as needed


# Convert every analytical theta profile to conductivity
sigma_matrices = {}

for scenario_name, time_dict in theta_results.items():

    conductivity_profiles = {}

    for t, theta_profile in time_dict.items():

        sigma_profile = theta_to_conductivity(
            theta=theta_profile,
            sigma_w=sigma_w,
            m_archie=m_archie
        )

        conductivity_profiles[t] = sigma_profile

    sigma_matrix = pd.DataFrame(
        conductivity_profiles,
        index=z
    )

    sigma_matrix.index.name = "depth_cm"

    sigma_matrices[scenario_name] = sigma_matrix

# %%
first_scenario = next(iter(sigma_matrices))

print("Displayed scenario:", first_scenario)
display(sigma_matrices[first_scenario].head())
# Out:
# Displayed scenario: sand000_silt000_clay100
#                  1         4         12        24        48
# depth_cm
# 1.000000   0.027732  0.025439  0.023788  0.022816  0.021894
# 7.685619   0.031586  0.028900  0.026968  0.025831  0.024753
# 14.371237  0.032896  0.030077  0.028049  0.026855  0.025724
# 21.056856  0.033729  0.030824  0.028734  0.027505  0.026340
# 27.742475  0.034345  0.031377  0.029242  0.027986  0.026796

# %% [markdown]
# ### 6. SimPEG Forward Model

# %% [markdown]
# #### 6.1 Forward Model TEM for electrical conductivity matrix

# %%
# SimPEG TEM forward model from the electrical conductivity matrix

def build_tem_simulation(
    layer_thicknesses_m,
    loop_side_length_m=20.0,
    height_m=0.0,
    tem_times=None
):
    """Build one layered TDEM simulation for all ensemble profiles."""

    if tem_times is None:
        tem_times = np.logspace(-7, -2, 61)

    layer_thicknesses_m = np.asarray(
        layer_thicknesses_m,
        dtype=float
    )

    n_layers = len(layer_thicknesses_m) + 1

    receiver = tdem.receivers.PointMagneticFluxDensity(   ### OR receiver = tdem.receivers.PointMagneticFluxTimeDerivative(
        locations=np.array([[0.0, 0.0, height_m]]),
        times=tem_times,
        orientation="z"
    )

    # Equivalent-area circular loop for a 20 m x 20 m square loop
    loop_area = loop_side_length_m**2
    loop_radius = np.sqrt(loop_area / np.pi)

    source = tdem.sources.CircularLoop(
        receiver_list=[receiver],
        location=np.array([0.0, 0.0, height_m]),
        radius=loop_radius,
        orientation="z",
        waveform=tdem.sources.StepOffWaveform()
    )

    survey = tdem.Survey([source])

    conductivity_map = maps.IdentityMap(nP=n_layers)

    simulation = tdem.simulation_1d.Simulation1DLayered(
        survey=survey,
        sigmaMap=conductivity_map,
        thicknesses=layer_thicknesses_m
    )

    return simulation, tem_times

# %% [markdown]
# #### 6.2 Build layered model at all times

# %%
# Run TEM forward model for every timestep

# All analytical scenarios use the same depth grid
first_sigma_matrix = next(iter(sigma_matrices.values()))

depth_m = first_sigma_matrix.index.to_numpy() / 100.0
layer_thicknesses_m = np.diff(depth_m)

tem_simulation, tem_times = build_tem_simulation(
    layer_thicknesses_m=layer_thicknesses_m,
    loop_side_length_m=20.0,
    height_m=0.0
)

tem_results = {}

for scenario_name, sigma_matrix in sigma_matrices.items():

    tem_results[scenario_name] = {}

    for drainage_time in sigma_matrix.columns:

        conductivity_profile = (
            sigma_matrix[drainage_time].to_numpy(dtype=float)
        )

        response = tem_simulation.dpred(conductivity_profile)

        tem_results[scenario_name][drainage_time] = response

# %%
tem_response_matrices = {}

for scenario_name, time_dict in tem_results.items():

    response_matrix = pd.DataFrame(
        time_dict,
        index=tem_times
    )

    response_matrix.index.name = "TEM_time_s"

    tem_response_matrices[scenario_name] = response_matrix

# %% [markdown]
# ### 6.3 Plot TEM response over time

# %%
def plot_tem_response(
    tem_response_matrices,
    scenario_name,
    time_min=None,
    time_max=None
):
    response_matrix = tem_response_matrices[scenario_name]

    if time_min is None:
        time_min = response_matrix.index.min()

    if time_max is None:
        time_max = response_matrix.index.max()

    time_mask = (
        (response_matrix.index >= time_min) &
        (response_matrix.index <= time_max)
    )

    if not np.any(time_mask):
        raise ValueError(
            "No TEM times fall within the selected window."
        )

    plt.figure(figsize=(8, 6))

    for drainage_time in response_matrix.columns:

        visible_response = response_matrix.loc[
            time_mask,
            drainage_time
        ]

        plt.loglog(
            visible_response.index,
            np.abs(visible_response),
            linewidth=2,
            label=f"{drainage_time} hr"
        )

    plt.xlabel("Time after transmitter shutoff [s]")
    plt.ylabel("Predicted magnetic flux density |B| [T]")
    plt.title(f"Predicted TDEM response: {scenario_name}")

    plt.grid(True, which="major", alpha=0.5)
    plt.grid(True, which="minor", alpha=0.15)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Select scenario for viewing

# %%
plot_tem_response(
    tem_response_matrices=tem_response_matrices,
    scenario_name="sand000_silt000_clay100",      ### edit scenario you want to see 
    time_min=1e-7,
    time_max=1e-4
)

# %% [markdown]
# ### 7. Processing TDEM Responses

# %%
# Compare the first and last modeled drainage states.
early_drainage_time = min(times)
late_drainage_time = max(times)

# Use the same receiver-time window used in the TDEM plot above.
comparison_time_min = 1e-7
comparison_time_max = 1e-4

print(f"Early drainage profile: {early_drainage_time} hr")
print(f"Late drainage profile: {late_drainage_time} hr")
# Out:
# Early drainage profile: 1 hr
# Late drainage profile: 48 hr

# %% [markdown]
# #### 7.1 Overlay early/late time responses for all soils

# %%
def plot_early_late_responses(
    tem_response_matrices,
    early_time,
    late_time,
    time_min=None,
    time_max=None
):
    """Plot all scenarios at the selected early and late drainage times."""

    fig, axes = plt.subplots(1, 2, figsize=(13, 5), sharex=True, sharey=True)
    colors = plt.cm.tab10(np.linspace(0, 1, len(tem_response_matrices)))

    for color, (scenario_name, response_matrix) in zip(
        colors, tem_response_matrices.items()
    ):
        time_mask = np.ones(len(response_matrix), dtype=bool)

        if time_min is not None:
            time_mask &= response_matrix.index.to_numpy() >= time_min
        if time_max is not None:
            time_mask &= response_matrix.index.to_numpy() <= time_max

        visible_times = response_matrix.index.to_numpy()[time_mask]

        for axis, drainage_time, label in zip(
            axes,
            [early_time, late_time],
            ["Early", "Late"]
        ):
            response = np.abs(
                response_matrix.loc[time_mask, drainage_time].to_numpy(dtype=float)
            )
            axis.loglog(
                visible_times,
                response,
                color=color,
                linewidth=2,
                label=scenario_name
            )
            axis.set_title(f"{label}: {drainage_time} hr drainage")
            axis.set_xlabel("Time after transmitter shutoff [s]")
            axis.grid(True, which="major", alpha=0.4)
            axis.grid(True, which="minor", alpha=0.12)

    axes[0].set_ylabel("Predicted magnetic flux density |B| [T]")
    axes[1].legend(title="Soil", bbox_to_anchor=(1.02, 1), loc="upper left")
    fig.suptitle("Early and late TDEM responses by soil")
    fig.tight_layout()
    plt.show()


plot_early_late_responses(
    tem_response_matrices=tem_response_matrices,
    early_time=early_drainage_time,
    late_time=late_drainage_time,
    time_min=comparison_time_min,
    time_max=comparison_time_max
)
# Out:
# C:\Users\natal\AppData\Local\Temp\ipykernel_55504\427068689.py:48: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   fig.tight_layout()

# %% [markdown]
# #### 7.2 Build vector response for both early-late and late-early for comparison

# %%
def build_soil_vectors(order="early_late"):
    """
    Build one response vector per soil using either:
    - early_late: [early response, late response]
    - late_early: [late response, early response]
    """

    soil_names = []
    vectors = []

    for soil_name, response_matrix in tem_response_matrices.items():

        early_response = response_matrix[early_drainage_time][comparison_mask]
        late_response = response_matrix[late_drainage_time][comparison_mask]

        early_log = np.log10(np.abs(early_response))
        late_log = np.log10(np.abs(late_response))

        if order == "early_late":
            vector = np.concatenate([early_log, late_log])

        elif order == "late_early":
            vector = np.concatenate([late_log, early_log])

        else:
            raise ValueError("order must be 'early_late' or 'late_early'")

        soil_names.append(soil_name)
        vectors.append(vector)

    return soil_names, np.vstack(vectors)

# %%
def build_early_late_feature_table(
    tem_response_matrices,
    early_time,
    late_time,
    time_min=None,
    time_max=None,
    response_floor=1e-30,
    order="early_late"
):
    """
    Return one log10 response vector per soil.

    order="early_late" builds:
        [early response, late response]

    order="late_early" builds:
        [late response, early response]
    """

    feature_rows = {}
    feature_columns = None

    for scenario_name, response_matrix in tem_response_matrices.items():

        time_mask = np.ones(len(response_matrix), dtype=bool)

        if time_min is not None:
            time_mask &= response_matrix.index.to_numpy() >= time_min
        if time_max is not None:
            time_mask &= response_matrix.index.to_numpy() <= time_max

        selected_tem_times = response_matrix.index.to_numpy()[time_mask]

        early_response = np.abs(
            response_matrix.loc[time_mask, early_time].to_numpy(dtype=float)
        )
        late_response = np.abs(
            response_matrix.loc[time_mask, late_time].to_numpy(dtype=float)
        )

        early_log_response = np.log10(np.maximum(early_response, response_floor))
        late_log_response = np.log10(np.maximum(late_response, response_floor))

        if order == "early_late":
            feature_vector = np.concatenate([
                early_log_response,
                late_log_response
            ])

            column_labels = (
                [f"early_{tem_time:.3e}_s" for tem_time in selected_tem_times]
                +
                [f"late_{tem_time:.3e}_s" for tem_time in selected_tem_times]
            )

        elif order == "late_early":
            feature_vector = np.concatenate([
                late_log_response,
                early_log_response
            ])

            column_labels = (
                [f"late_{tem_time:.3e}_s" for tem_time in selected_tem_times]
                +
                [f"early_{tem_time:.3e}_s" for tem_time in selected_tem_times]
            )

        else:
            raise ValueError("order must be 'early_late' or 'late_early'")

        feature_rows[scenario_name] = feature_vector

        if feature_columns is None:
            feature_columns = column_labels

    return pd.DataFrame.from_dict(
        feature_rows,
        orient="index",
        columns=feature_columns
    )

# %%
clustering_features_EL = build_early_late_feature_table(
    tem_response_matrices=tem_response_matrices,
    early_time=early_drainage_time,
    late_time=late_drainage_time,
    time_min=comparison_time_min,
    time_max=comparison_time_max,
    order="early_late"
)

clustering_features_LE = build_early_late_feature_table(
    tem_response_matrices=tem_response_matrices,
    early_time=early_drainage_time,
    late_time=late_drainage_time,
    time_min=comparison_time_min,
    time_max=comparison_time_max,
    order="late_early"
)

display(clustering_features_EL.iloc[:, :5])
#display(clustering_features_LE.iloc[:, :5])

clustering_features = clustering_features_EL  ## OR  clustering_features_LE
# Out:
#                          early_1.000e-07_s  early_1.212e-07_s  \
# sand000_silt000_clay100          -7.305340          -7.316707
# sand000_silt004_clay096          -7.303863          -7.314884
# sand000_silt008_clay092          -7.302755          -7.313514
# sand000_silt012_clay088          -7.301953          -7.312521
# sand000_silt016_clay084          -7.301382          -7.311813
# ...                                    ...                ...
# sand092_silt004_clay004          -7.382878          -7.407034
# sand092_silt008_clay000          -7.382900          -7.406522
# sand096_silt000_clay004          -7.414966          -7.443884
# sand096_silt004_clay000          -7.417271          -7.445812
# sand100_silt000_clay000          -7.460242          -7.495025
#
#                          early_1.468e-07_s  early_1.778e-07_s  \
# sand000_silt000_clay100          -7.330837          -7.348481
# sand000_silt004_clay096          -7.328576          -7.345665
# sand000_silt008_clay092          -7.326874          -7.343542
# sand000_silt012_clay088          -7.325638          -7.341997
# sand000_silt016_clay084          -7.324758          -7.340898
# ...                                    ...                ...
# sand092_silt004_clay004          -7.435762          -7.469731
# sand092_silt008_clay000          -7.434538          -7.467606
# sand096_silt000_clay004          -7.477492          -7.516201
# sand096_silt004_clay000          -7.478854          -7.516792
# sand100_silt000_clay000          -7.534520          -7.578864
#
#                          early_2.154e-07_s
# sand000_silt000_clay100          -7.370554
# sand000_silt004_clay096          -7.367046
# sand000_silt008_clay092          -7.364395
# sand000_silt012_clay088          -7.362463
# sand000_silt016_clay084          -7.361087
# ...                                    ...
# sand092_silt004_clay004          -7.509545
# sand092_silt008_clay000          -7.506330
# sand096_silt000_clay004          -7.560348
# sand096_silt004_clay000          -7.559962
# sand100_silt000_clay000          -7.628098
#
# [351 rows x 5 columns]

# %% [markdown]
# #### Option to calculate similarity exsists in Analytical_ForwardModel section 8.3. Can be overwhelmed by large number of cases. return there for code if needed

# %% [markdown]
# ### 8. Data analysis and processing for "True" parameter scenarios

# %% [markdown]
# ##### Theta(psi), K(theta), vg parameters to be used for more "true" clustering. Results to be compared with TEM response for analysis

# %% [markdown]
# #### 8.1 Define van Genuchten relationships

# %%
def theta_vg_pressure_head(psi_cm, theta_r, theta_s, alpha, vg_n):
    """Water content from the van Genuchten retention curve."""
    psi_cm = np.asarray(psi_cm, dtype=float)
    m = 1 - (1 / vg_n)

    theta = np.full_like(psi_cm, theta_s, dtype=float)
    unsat = psi_cm < 0
    Se = (1 + (alpha * np.abs(psi_cm[unsat])) ** vg_n) ** (-m)
    theta[unsat] = theta_r + Se * (theta_s - theta_r)

    return theta


def k_vg_pressure_head(psi_cm, theta_r, theta_s, alpha, vg_n, Ks, l=0.5):
    """Hydraulic conductivity from the van Genuchten-Mualem K function."""
    theta = theta_vg_pressure_head(
        psi_cm=psi_cm,
        theta_r=theta_r,
        theta_s=theta_s,
        alpha=alpha,
        vg_n=vg_n
    )

    Se = (theta - theta_r) / (theta_s - theta_r)
    Se = np.clip(Se, 1e-8, 1.0)
    Kr = kr_vg_mualem(Se, vg_n=vg_n, l=l)

    return Ks * Kr
### gives absolute hydraulic conductivity

# %% [markdown]
# #### 8.2 Build feature tables for comparitive clustering

# %%
pressure_head_cm = np.linspace(0, -300, 10)

def build_hydraulic_feature_tables(scenarios_to_run, pressure_head_cm):
    """
    Build advisor-requested clustering feature tables:
    1. theta(psi)
    2. K(psi)
    3. theta(psi) and K(psi)
    4. van Genuchten parameters
    """

    theta_rows = {}
    k_rows = {}
    vg_rows = {}

    for scenario_name, params in scenarios_to_run.items():

        theta_curve = theta_vg_pressure_head(
            psi_cm=pressure_head_cm,
            theta_r=params["theta_r"],
            theta_s=params["theta_s"],
            alpha=params["alpha"],
            vg_n=params["vg_n"]
        )

        k_curve = k_vg_pressure_head(
            psi_cm=pressure_head_cm,
            theta_r=params["theta_r"],
            theta_s=params["theta_s"],
            alpha=params["alpha"],
            vg_n=params["vg_n"],
            Ks=params["Ks"],
            l=params.get("l", 0.5)
        )

        theta_rows[scenario_name] = theta_curve

        # K spans orders of magnitude, so cluster log10(K), not raw K.
        k_rows[scenario_name] = np.log10(np.maximum(k_curve, 1e-30))

        vg_rows[scenario_name] = {
            "theta_r": params["theta_r"],
            "theta_s": params["theta_s"],
            "log10_alpha": np.log10(params["alpha"]),
            "vg_n": params["vg_n"],
            "log10_Ks": np.log10(params["Ks"])
        }

    theta_columns = [f"theta_psi_{psi:.1f}_cm" for psi in pressure_head_cm]
    k_columns = [f"log10_K_psi_{psi:.1f}_cm" for psi in pressure_head_cm]

    theta_feature_df = pd.DataFrame.from_dict(
        theta_rows,
        orient="index",
        columns=theta_columns
    )

    k_feature_df = pd.DataFrame.from_dict(
        k_rows,
        orient="index",
        columns=k_columns
    )

    theta_k_feature_df = pd.concat(
        [theta_feature_df, k_feature_df],
        axis=1
    )

    vg_feature_df = pd.DataFrame.from_dict(
        vg_rows,
        orient="index"
    )

    return {
        "theta_psi": theta_feature_df,
        "K_psi": k_feature_df,
        "theta_and_K_psi": theta_k_feature_df,
        "vg_params": vg_feature_df
    }


hydraulic_feature_tables = build_hydraulic_feature_tables(
    scenarios_to_run=scenarios_to_run,
    pressure_head_cm=pressure_head_cm
)

display(hydraulic_feature_tables["theta_psi"].head())
display(hydraulic_feature_tables["K_psi"].head())
display(hydraulic_feature_tables["vg_params"].head())
# Out:
#                          theta_psi_0.0_cm  theta_psi_-33.3_cm  \
# sand000_silt000_clay100            0.4968            0.476959
# sand000_silt004_clay096            0.5058            0.484201
# sand000_silt008_clay092            0.5130            0.489330
# sand000_silt012_clay088            0.5185            0.492794
# sand000_silt016_clay084            0.5225            0.494815
#
#                          theta_psi_-66.7_cm  theta_psi_-100.0_cm  \
# sand000_silt000_clay100            0.460820             0.448379
# sand000_silt004_clay096            0.467139             0.454187
# sand000_silt008_clay092            0.471034             0.457330
# sand000_silt012_clay088            0.473124             0.458519
# sand000_silt016_clay084            0.473676             0.458073
#
#                          theta_psi_-133.3_cm  theta_psi_-166.7_cm  \
# sand000_silt000_clay100             0.438443             0.430251
# sand000_silt004_clay096             0.443936             0.435533
# sand000_silt008_clay092             0.446573             0.437802
# sand000_silt012_clay088             0.447124             0.437874
# sand000_silt016_clay084             0.445956             0.436153
#
#                          theta_psi_-200.0_cm  theta_psi_-233.3_cm  \
# sand000_silt000_clay100             0.423322             0.417344
# sand000_silt004_clay096             0.428453             0.422363
# sand000_silt008_clay092             0.430443             0.424129
# sand000_silt012_clay088             0.430136             0.423515
# sand000_silt016_clay084             0.427977             0.420997
#
#                          theta_psi_-266.7_cm  theta_psi_-300.0_cm
# sand000_silt000_clay100             0.412103             0.407449
# sand000_silt004_clay096             0.417034             0.412310
# sand000_silt008_clay092             0.418619             0.413742
# sand000_silt012_clay088             0.417748             0.412652
# sand000_silt016_clay084             0.414929             0.409576
#                          log10_K_psi_0.0_cm  log10_K_psi_-33.3_cm  \
# sand000_silt000_clay100           -0.113274             -1.832200
# sand000_silt004_clay096           -0.125663             -1.903343
# sand000_silt008_clay092           -0.129791             -1.937386
# sand000_silt012_clay088           -0.131993             -1.936671
# sand000_silt016_clay084           -0.136182             -1.917742
#
#                          log10_K_psi_-66.7_cm  log10_K_psi_-100.0_cm  \
# sand000_silt000_clay100             -2.278884              -2.587384
# sand000_silt004_clay096             -2.361066              -2.675042
# sand000_silt008_clay092             -2.405803              -2.725592
# sand000_silt012_clay088             -2.413444              -2.738325
# sand000_silt016_clay084             -2.401368              -2.730925
#
#                          log10_K_psi_-133.3_cm  log10_K_psi_-166.7_cm  \
# sand000_silt000_clay100              -2.824947              -3.018439
# sand000_silt004_clay096              -2.915757              -3.111233
# sand000_silt008_clay092              -2.969968              -3.167968
# sand000_silt012_clay088              -2.986196              -3.186789
# sand000_silt016_clay084              -2.982230              -3.185495
#
#                          log10_K_psi_-200.0_cm  log10_K_psi_-233.3_cm  \
# sand000_silt000_clay100              -3.181728              -3.322985
# sand000_silt004_clay096              -3.275846              -3.418024
# sand000_silt008_clay092              -3.334435              -3.478038
# sand000_silt012_clay088              -3.355283              -3.500533
# sand000_silt016_clay084              -3.356159              -3.503224
#
#                          log10_K_psi_-266.7_cm  log10_K_psi_-300.0_cm
# sand000_silt000_clay100              -3.447448              -3.558681
# sand000_silt004_clay096              -3.543146              -3.654862
# sand000_silt008_clay092              -3.604294              -3.716936
# sand000_silt012_clay088              -3.628167              -3.741988
# sand000_silt016_clay084              -3.632414              -3.747593
#                          theta_r  theta_s  log10_alpha    vg_n  log10_Ks
# sand000_silt000_clay100   0.1095   0.4968    -1.798603  1.1548 -0.113274
# sand000_silt004_clay096   0.1081   0.5058    -1.764472  1.1520 -0.125663
# sand000_silt008_clay092   0.1074   0.5130    -1.735182  1.1541 -0.129791
# sand000_silt012_clay088   0.1074   0.5185    -1.716699  1.1603 -0.131993
# sand000_silt016_clay084   0.1076   0.5225    -1.705534  1.1692 -0.136182

# %% [markdown]
# Combine all exsisting feature tables

# %%
all_feature_tables = {
    "TDEM_response": clustering_features_EL,
    "theta_psi": hydraulic_feature_tables["theta_psi"],
    "K_psi": hydraulic_feature_tables["K_psi"],
    "theta_and_K_psi": hydraulic_feature_tables["theta_and_K_psi"],
    "vg_params": hydraulic_feature_tables["vg_params"]
}

display(all_feature_tables.keys())
# Out:
# dict_keys(['TDEM_response', 'theta_psi', 'K_psi', 'theta_and_K_psi', 'vg_params'])

# %% [markdown]
# ### 8.3 Find centroids / Select representative soils
# for all features (??? before k-means)

# %%
def find_centroids(feature_df, kmeans_model, labels):
    """
    Find the actual soil/scenario closest to each K-means centroid.
    """

    X = feature_df.to_numpy(dtype=float)
    representative_rows = []

    for cluster_id in sorted(np.unique(labels)):

        cluster_member_positions = np.where(labels == cluster_id)[0]
        cluster_centroid = kmeans_model.cluster_centers_[cluster_id]

        distances_to_centroid = np.linalg.norm(
            X[cluster_member_positions] - cluster_centroid,
            axis=1
        )

        closest_member_position = cluster_member_positions[
            np.argmin(distances_to_centroid)
        ]

        representative_soil = feature_df.index[closest_member_position]

        representative_rows.append({
            "cluster": cluster_id,
            "representative_soil": representative_soil,
            "distance_to_centroid": distances_to_centroid.min(),
            "n_soils_in_cluster": len(cluster_member_positions)
        })

    return pd.DataFrame(representative_rows)

# %% [markdown]
# ### 8.4 K-means clustering for feature tables

# %%
def run_kmeans_feature_clustering(feature_df, k, max_k=10, scale_features=True):
    """
    Run K-means clustering and elbow analysis for one feature table.
    """

    if scale_features:
        scaler = StandardScaler()
        X = scaler.fit_transform(feature_df.to_numpy(dtype=float))
    else:
        scaler = None
        X = feature_df.to_numpy(dtype=float)

    scaled_feature_df = pd.DataFrame(
        X,
        index=feature_df.index,
        columns=feature_df.columns
    )

    # Final clustering for the selected k
    kmeans = KMeans(n_clusters=k, random_state=0, n_init=20)
    labels = kmeans.fit_predict(X)

    all_soils_cluster_df = pd.DataFrame({
        "soil": feature_df.index,
        "cluster": labels
    })

    centroids = find_centroids(
        feature_df=scaled_feature_df,
        kmeans_model=kmeans,
        labels=labels
    )

    # Elbow and silhouette analysis
    inertias = []
    silhouette_scores = []

    n_samples = feature_df.shape[0]
    k_values = range(1, min(max_k, n_samples) + 1)

    for k_test in k_values:
        test_kmeans = KMeans(
            n_clusters=k_test,
            random_state=0,
            n_init=20
        )

        test_labels = test_kmeans.fit_predict(X)

        inertias.append(test_kmeans.inertia_)

        if 1 < k_test < n_samples:
            silhouette_scores.append(
                silhouette_score(X, test_labels)
            )
        else:
            silhouette_scores.append(np.nan)

    elbow_df = pd.DataFrame({
        "k": list(k_values),
        "inertia": inertias,
        "silhouette_score": silhouette_scores
    })

    return {
        "feature_df": feature_df,
        "scaled_feature_df": scaled_feature_df,
        "kmeans": kmeans,
        "labels": labels,
        "all_soils_cluster_df": all_soils_cluster_df,
        "centroids": centroids,
        "elbow_df": elbow_df,
        "scaler": scaler
    }

# %% [markdown]
# ### 8.5 Cluster results

# %%
k = 3  # change to 3 or 5 depending on the analysis version

all_clustering_results = {}

for feature_name, feature_df in all_feature_tables.items():

    all_clustering_results[feature_name] = run_kmeans_feature_clustering(
        feature_df=feature_df,
        k=k,
        max_k=10,
        scale_features=True
    )

    print(f"\nFinished clustering: {feature_name}")
    display(all_clustering_results[feature_name]["all_soils_cluster_df"].head())
    display(all_clustering_results[feature_name]["centroids"])
# Out:
# Finished clustering: TDEM_response
#                       soil  cluster
# 0  sand000_silt000_clay100        1
# 1  sand000_silt004_clay096        1
# 2  sand000_silt008_clay092        1
# 3  sand000_silt012_clay088        1
# 4  sand000_silt016_clay084        1
#    cluster      representative_soil  distance_to_centroid  n_soils_in_cluster
# 0        0  sand040_silt048_clay012              0.497874                 153
# 1        1  sand020_silt028_clay052              0.292080                 189
# 2        2  sand092_silt004_clay004              1.437214                   9
# Finished clustering: theta_psi
#                       soil  cluster
# 0  sand000_silt000_clay100        0
# 1  sand000_silt004_clay096        0
# 2  sand000_silt008_clay092        0
# 3  sand000_silt012_clay088        0
# 4  sand000_silt016_clay084        0
#    cluster      representative_soil  distance_to_centroid  n_soils_in_cluster
# 0        0  sand016_silt032_clay052              0.232921                 206
# 1        1  sand084_silt008_clay008              0.296467                  31
# 2        2  sand048_silt024_clay028              0.078974                 114
# Finished clustering: K_psi
#                       soil  cluster
# 0  sand000_silt000_clay100        1
# 1  sand000_silt004_clay096        1
# 2  sand000_silt008_clay092        1
# 3  sand000_silt012_clay088        1
# 4  sand000_silt016_clay084        1
#    cluster      representative_soil  distance_to_centroid  n_soils_in_cluster
# 0        0  sand040_silt052_clay008              0.183820                  66
# 1        1  sand068_silt008_clay024              0.262225                 177
# 2        2  sand052_silt036_clay012              0.378126                 108
# Finished clustering: theta_and_K_psi
#                       soil  cluster
# 0  sand000_silt000_clay100        2
# 1  sand000_silt004_clay096        2
# 2  sand000_silt008_clay092        2
# 3  sand000_silt012_clay088        2
# 4  sand000_silt016_clay084        2
#    cluster      representative_soil  distance_to_centroid  n_soils_in_cluster
# 0        0  sand008_silt076_clay016              0.794345                 107
# 1        1  sand068_silt020_clay012              0.399763                  93
# 2        2  sand024_silt020_clay056              0.256745                 151
# Finished clustering: vg_params
#                       soil  cluster
# 0  sand000_silt000_clay100        0
# 1  sand000_silt004_clay096        0
# 2  sand000_silt008_clay092        0
# 3  sand000_silt012_clay088        0
# 4  sand000_silt016_clay084        0
#    cluster      representative_soil  distance_to_centroid  n_soils_in_cluster
# 0        0  sand028_silt024_clay048              0.146391                 191
# 1        1  sand080_silt008_clay012              0.522450                  67
# 2        2  sand012_silt076_clay012              0.489829                  93

# %% [markdown]
# #### 8.3 SELECT active clustering option for visualization

# %% [markdown]
# SELECT OPTION FOR ALL VISUALIZATION
#
# Options: "TDEM_response, theta_psi, K_psi, theta_and_K_psi, vg_params"

# %%
active_clustering_name = "theta_psi"
# Options:
# "TDEM_response"
# "theta_psi"
# "K_psi"
# "theta_and_K_psi"
# "vg_params"

active_result = all_clustering_results[active_clustering_name]

all_soils_cluster_df = active_result["all_soils_cluster_df"]
centroids = active_result["centroids"]
elbow_df = active_result["elbow_df"]
active_feature_df = active_result["feature_df"]
active_labels = active_result["labels"]

display(all_soils_cluster_df.head())
display(centroids)
display(elbow_df)
# Out:
#                       soil  cluster
# 0  sand000_silt000_clay100        0
# 1  sand000_silt004_clay096        0
# 2  sand000_silt008_clay092        0
# 3  sand000_silt012_clay088        0
# 4  sand000_silt016_clay084        0
#    cluster      representative_soil  distance_to_centroid  n_soils_in_cluster
# 0        0  sand016_silt032_clay052              0.232921                 206
# 1        1  sand084_silt008_clay008              0.296467                  31
# 2        2  sand048_silt024_clay028              0.078974                 114
#     k      inertia  silhouette_score
# 0   1  3510.000000               NaN
# 1   2  1226.635370          0.588990
# 2   3   658.693747          0.548857
# 3   4   438.402157          0.446138
# 4   5   310.134315          0.450933
# 5   6   239.517601          0.431860
# 6   7   193.915787          0.409965
# 7   8   163.930053          0.413748
# 8   9   142.366852          0.398221
# 9  10   126.687038          0.374671

# %% [markdown]
# ### 9. Visualization of results

# %%
cluster_summary = (
    active_result["all_soils_cluster_df"]
    .groupby("cluster")
    .agg(
        n_soils=("soil", "count"),
        example_soils=("soil", lambda x: ", ".join(x.head(5)))
    )
    .reset_index()
)

cluster_summary = cluster_summary.merge(
    active_result["centroids"][["cluster", "representative_soil"]],
    on="cluster",
    how="left"
)

display(cluster_summary)
# Out:
#    cluster  n_soils                                      example_soils  \
# 0        0      206  sand000_silt000_clay100, sand000_silt004_clay0...
# 1        1       31  sand068_silt024_clay008, sand068_silt028_clay0...
# 2        2      114  sand032_silt032_clay036, sand032_silt036_clay0...
#
#        representative_soil
# 0  sand016_silt032_clay052
# 1  sand084_silt008_clay008
# 2  sand048_silt024_clay028

# %% [markdown]
# #### 9.1 Elbow plot

# %%
fig, ax = plt.subplots(figsize=(7, 5))

ax.plot(
    elbow_df["k"],
    elbow_df["inertia"],
    marker="o",
    linewidth=2
)

ax.set_xlabel("Number of clusters, k")
ax.set_ylabel("K-means inertia")
ax.set_title(
    f"Elbow Method for {active_clustering_name} Clustering"
)
ax.set_xticks(elbow_df["k"])
ax.grid(True, linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.2 Sand clay plot with clustering

# %%
cluster_sand_clay_df = all_soils_cluster_df.copy()

texture_parts = cluster_sand_clay_df["soil"].str.extract(
    r"sand(?P<sand>\d+)_silt(?P<silt>\d+)_clay(?P<clay>\d+)"
)

cluster_sand_clay_df[["sand", "silt", "clay"]] = texture_parts.astype(float)

fig, ax = plt.subplots(figsize=(8, 7))

scatter = ax.scatter(
    cluster_sand_clay_df["sand"],
    cluster_sand_clay_df["clay"],
    c=cluster_sand_clay_df["cluster"],
    cmap="tab10",
    s=110,
    edgecolor="black",
    linewidth=0.7
)

ax.plot([0, 100], [100, 0], color="black", linewidth=1.5)

ax.set_xlim(-3, 103)
ax.set_ylim(-3, 103)
ax.set_aspect("equal")

ax.set_xlabel("Sand (%)")
ax.set_ylabel("Clay (%)")
ax.set_title(
    f"K-Means Clusters on Sand-Clay Surface\n{active_clustering_name} ({k} Clusters)"
)

ax.grid(True, linestyle="--", alpha=0.35)

ax.legend(
    *scatter.legend_elements(),
    title="Cluster",
    loc="upper right"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.3 Soil texture triangle with clustering

# %%
cluster_plot_df = all_soils_cluster_df.copy()

texture_parts = cluster_plot_df["soil"].str.extract(
    r"sand(?P<sand>\d+)_silt(?P<silt>\d+)_clay(?P<clay>\d+)"
)

cluster_plot_df[["sand", "silt", "clay"]] = texture_parts.astype(float)

# Ternary coordinates:
# left corner = clay, right corner = sand, top corner = silt
sand = cluster_plot_df["sand"] / 100
silt = cluster_plot_df["silt"] / 100

cluster_plot_df["ternary_x"] = sand + 0.5 * silt
cluster_plot_df["ternary_y"] = (np.sqrt(3) / 2) * silt

representative_plot_df = cluster_plot_df[
    cluster_plot_df["soil"].isin(centroids["representative_soil"])
].copy()

fig, ax = plt.subplots(figsize=(10.5, 8))

# Draw triangle boundary
triangle_x = [0, 1, 0.5, 0]
triangle_y = [0, 0, np.sqrt(3) / 2, 0]
ax.plot(triangle_x, triangle_y, color="black", linewidth=1.8)

# Add light gridlines every 20%
for p in np.arange(0.2, 1.0, 0.2):

    # constant silt
    ax.plot(
        [0.5 * p, 1 - 0.5 * p],
        [(np.sqrt(3) / 2) * p, (np.sqrt(3) / 2) * p],
        color="lightgray",
        linewidth=0.8,
        zorder=0
    )

    # constant sand
    ax.plot(
        [p, 0.5 + 0.5 * p],
        [0, (np.sqrt(3) / 2) * (1 - p)],
        color="lightgray",
        linewidth=0.8,
        zorder=0
    )

    # constant clay
    ax.plot(
        [1 - p, 0.5 * (1 - p)],
        [0, (np.sqrt(3) / 2) * (1 - p)],
        color="lightgray",
        linewidth=0.8,
        zorder=0
    )

# All soils colored by active cluster
scatter = ax.scatter(
    cluster_plot_df["ternary_x"],
    cluster_plot_df["ternary_y"],
    c=cluster_plot_df["cluster"],
    cmap="tab10",
    s=95,
    edgecolor="black",
    linewidth=0.6,
    alpha=0.9,
    zorder=3
)

# Representative soils closest to K-means centroids
representative_scatter = ax.scatter(
    representative_plot_df["ternary_x"],
    representative_plot_df["ternary_y"],
    marker="*",
    s=520,
    facecolor="red",
    edgecolor="black",
    linewidth=1.3,
    zorder=5,
    label="Representative soil"
)

# Short labels inside the plot
for _, row in representative_plot_df.iterrows():
    ax.annotate(
        f"C{int(row['cluster'])}",
        (row["ternary_x"], row["ternary_y"]),
        xytext=(7, 7),
        textcoords="offset points",
        fontsize=11,
        fontweight="bold",
        color="red"
    )

# Corner labels
ax.text(-0.04, -0.045, "100% Clay", ha="right", va="top", fontsize=12)
ax.text(1.04, -0.045, "100% Sand", ha="left", va="top", fontsize=12)
ax.text(
    0.5,
    np.sqrt(3) / 2 + 0.055,
    "100% Silt",
    ha="center",
    va="bottom",
    fontsize=12
)

ax.set_title(
    f"K-Means Clusters Across Soil Texture Space\n{active_clustering_name} ({k} Clusters)",
    fontsize=15,
    pad=28
)

# Cluster color legend
cluster_legend = ax.legend(
    *scatter.legend_elements(),
    title="Cluster",
    loc="center left",
    bbox_to_anchor=(1.02, 0.62),
    frameon=True
)

ax.add_artist(cluster_legend)

# Representative marker legend
representative_legend = ax.legend(
    handles=[representative_scatter],
    labels=["Representative soil"],
    loc="center left",
    bbox_to_anchor=(1.02, 0.43),
    frameon=True
)

ax.add_artist(representative_legend)

# Side label box for representative soils
representative_label_lines = []

for _, row in representative_plot_df.sort_values("cluster").iterrows():
    representative_label_lines.append(
        f"C{int(row['cluster'])}: {row['soil']}"
    )

representative_label_text = (
    "Representative soils\n"
    + "\n".join(representative_label_lines)
)

ax.text(
    1.02,
    0.25,
    representative_label_text,
    transform=ax.transAxes,
    ha="left",
    va="top",
    fontsize=10,
    bbox=dict(
        boxstyle="round,pad=0.4",
        facecolor="white",
        edgecolor="lightgray",
        alpha=0.95
    )
)

ax.set_aspect("equal")
ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.4 Water content vs negative pressure head

# %%
pressure_head_cm = np.linspace(0, -300, 10)
negative_pressure_head_cm = -pressure_head_cm

fig, ax = plt.subplots(figsize=(7, 6))

for _, row in centroids.sort_values("cluster").iterrows():

    cluster_id = int(row["cluster"])
    scenario_name = row["representative_soil"]

    params = scenarios_to_run[scenario_name]

    theta_curve = theta_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"]
    )

    ax.plot(
        theta_curve,
        negative_pressure_head_cm,
        marker="o",
        linewidth=2.2,
        label=f"C{cluster_id}: {scenario_name}"
    )

ax.set_xlabel("Water content, theta")
ax.set_ylabel("Negative pressure head, -psi [cm]")

ax.set_title(
    f"Water Content vs. Negative Pressure Head\n"
    f"Representative Soils by {active_clustering_name} ({k} Clusters)"
)

ax.grid(True, linestyle="--", alpha=0.35)
ax.legend(title="Representative soil")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.5 Water content vs psi for all soils with grouping by cluster

# %%
pressure_head_cm = np.linspace(0, -300, 10)
negative_pressure_head_cm = -pressure_head_cm

fig, ax = plt.subplots(figsize=(9, 6.8))

cmap = plt.get_cmap("tab10")

# -------------------------------------------------
# Plot all soils as background cluster-colored curves
# -------------------------------------------------
for _, row in all_soils_cluster_df.iterrows():

    scenario_name = row["soil"]
    cluster_id = int(row["cluster"])
    params = scenarios_to_run[scenario_name]

    theta_curve = theta_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"]
    )

    ax.plot(
        theta_curve,
        negative_pressure_head_cm,
        color=cmap(cluster_id),
        linewidth=1.0,
        alpha=0.35,
        zorder=1
    )

# -------------------------------------------------
# Plot representative centroid soils in bold cluster colors
# -------------------------------------------------
rep_handles = []

for _, row in centroids.sort_values("cluster").iterrows():

    cluster_id = int(row["cluster"])
    scenario_name = row["representative_soil"]
    params = scenarios_to_run[scenario_name]

    theta_curve = theta_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"]
    )

    line, = ax.plot(
        theta_curve,
        negative_pressure_head_cm,
        color=cmap(cluster_id),
        linewidth=3.1,
        alpha=1.0,
        linestyle="-",
        marker="o",
        markersize=4.8,
        markeredgecolor="black",
        markeredgewidth=0.5,
        zorder=5,
        label=f"C{cluster_id} representative"
    )

    rep_handles.append(line)

# -------------------------------------------------
# Axes formatting
# -------------------------------------------------
ax.set_xlabel("Water content, theta", fontsize=12, labelpad=7)
ax.set_ylabel("Negative pressure head, -psi [cm]", fontsize=12, labelpad=8)

ax.set_title(
    f"Water Retention Curves Colored by {active_clustering_name} Clusters "
    f"({k} Clusters)",
    fontsize=15,
    pad=10
)

ax.set_xlim(0.035, 0.615)
ax.set_ylim(-8, 315)

ax.grid(True, linestyle="--", alpha=0.28)
ax.tick_params(labelsize=11)

# -------------------------------------------------
# Legend handles
# -------------------------------------------------
cluster_handles = [
    plt.Line2D(
        [0], [0],
        color=cmap(int(cluster_id)),
        linewidth=3,
        alpha=0.8,
        label=f"Cluster {int(cluster_id)}"
    )
    for cluster_id in sorted(all_soils_cluster_df["cluster"].unique())
]

style_handles = [
    plt.Line2D(
        [0], [0],
        color="black",
        linewidth=1.0,
        alpha=0.35,
        label="All soil curves"
    ),
    plt.Line2D(
        [0], [0],
        color="black",
        linewidth=3.1,
        marker="o",
        markersize=4.8,
        markeredgecolor="black",
        markeredgewidth=0.5,
        label="Centroid representative"
    )
]

# -------------------------------------------------
# Compact legends below graph
# -------------------------------------------------
fig.legend(
    handles=style_handles,
    title="Curve type",
    loc="lower center",
    bbox_to_anchor=(0.25, 0.045),
    ncol=2,
    frameon=True,
    fontsize=9.0,
    title_fontsize=10.0,
    handlelength=2.2,
    columnspacing=1.5
)

fig.legend(
    handles=cluster_handles,
    title="Cluster color",
    loc="lower center",
    bbox_to_anchor=(0.75, 0.045),
    ncol=len(cluster_handles),
    frameon=True,
    fontsize=9.0,
    title_fontsize=10.0,
    handlelength=2.0,
    columnspacing=1.1
)

# -------------------------------------------------
# Keep most space for the graph while leaving room for legends
# -------------------------------------------------
fig.subplots_adjust(
    left=0.09,
    right=0.985,
    top=0.88,
    bottom=0.23
)

plt.show()

# %% [markdown]
# ### 9.6 Water content vs K for cluster centroids

# %%
pressure_head_cm = np.linspace(0, -300, 10)

fig, ax = plt.subplots(figsize=(7, 6))

for _, row in centroids.sort_values("cluster").iterrows():

    cluster_id = int(row["cluster"])
    scenario_name = row["representative_soil"]

    params = scenarios_to_run[scenario_name]

    theta_curve = theta_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"]
    )

    k_curve = k_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"],
        Ks=params["Ks"],
        l=params.get("l", 0.5)
    )

    ax.plot(
        theta_curve,
        k_curve,
        marker="o",
        linewidth=2.2,
        label=f"C{cluster_id}: {scenario_name}"
    )

ax.set_xlabel("Water content, theta")
ax.set_ylabel("Hydraulic conductivity, K [cm/hr]")

ax.set_title(
    f"Water Content vs. Hydraulic Conductivity\n"
    f"Representative Soils by {active_clustering_name} ({k} Clusters)"
)

ax.set_yscale("log")
ax.grid(True, linestyle="--", alpha=0.35)
ax.legend(title="Representative soil")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9.7 Water content vs K for all soils with cluster grouping

# %%
pressure_head_cm = np.linspace(0, -300, 10)

fig, ax = plt.subplots(figsize=(9, 6.8))

cmap = plt.get_cmap("tab10")

# -------------------------------------------------
# Plot all soils as background cluster-colored curves
# -------------------------------------------------
for _, row in all_soils_cluster_df.iterrows():

    scenario_name = row["soil"]
    cluster_id = int(row["cluster"])
    params = scenarios_to_run[scenario_name]

    theta_curve = theta_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"]
    )

    k_curve = k_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"],
        Ks=params["Ks"],
        l=params.get("l", 0.5)
    )

    ax.plot(
        theta_curve,
        k_curve,
        color=cmap(cluster_id),
        linewidth=1.0,
        alpha=0.35,
        zorder=1
    )

# -------------------------------------------------
# Plot representative centroid soils in bold cluster colors
# -------------------------------------------------
rep_handles = []

for _, row in centroids.sort_values("cluster").iterrows():

    cluster_id = int(row["cluster"])
    scenario_name = row["representative_soil"]
    params = scenarios_to_run[scenario_name]

    theta_curve = theta_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"]
    )

    k_curve = k_vg_pressure_head(
        psi_cm=pressure_head_cm,
        theta_r=params["theta_r"],
        theta_s=params["theta_s"],
        alpha=params["alpha"],
        vg_n=params["vg_n"],
        Ks=params["Ks"],
        l=params.get("l", 0.5)
    )

    line, = ax.plot(
        theta_curve,
        k_curve,
        color=cmap(cluster_id),
        linewidth=3.1,
        alpha=1.0,
        linestyle="-",
        marker="o",
        markersize=4.8,
        markeredgecolor="black",
        markeredgewidth=0.5,
        zorder=5,
        label=f"C{cluster_id} representative"
    )

    rep_handles.append(line)

# -------------------------------------------------
# Axes formatting
# -------------------------------------------------
ax.set_xlabel("Water content, theta", fontsize=12, labelpad=7)
ax.set_ylabel("Hydraulic conductivity, K [cm/hr]", fontsize=12, labelpad=8)

ax.set_title(
    f"Hydraulic Conductivity Curves Colored by {active_clustering_name} "
    f"Clusters ({k} Clusters)",
    fontsize=15,
    pad=10
)

ax.set_xlim(0.035, 0.615)
ax.set_yscale("log")
ax.set_ylim(1e-8, 2e2)

ax.grid(True, linestyle="--", alpha=0.28)
ax.tick_params(labelsize=11)

# -------------------------------------------------
# Legend handles
# -------------------------------------------------
cluster_handles = [
    plt.Line2D(
        [0], [0],
        color=cmap(int(cluster_id)),
        linewidth=3,
        alpha=0.8,
        label=f"Cluster {int(cluster_id)}"
    )
    for cluster_id in sorted(all_soils_cluster_df["cluster"].unique())
]

style_handles = [
    plt.Line2D(
        [0], [0],
        color="black",
        linewidth=1.0,
        alpha=0.35,
        label="All soil curves"
    ),
    plt.Line2D(
        [0], [0],
        color="black",
        linewidth=3.1,
        marker="o",
        markersize=4.8,
        markeredgecolor="black",
        markeredgewidth=0.5,
        label="Centroid representative"
    )
]

# -------------------------------------------------
# Compact legends below graph
# -------------------------------------------------
fig.legend(
    handles=style_handles,
    title="Curve type",
    loc="lower center",
    bbox_to_anchor=(0.25, 0.045),
    ncol=2,
    frameon=True,
    fontsize=9.0,
    title_fontsize=10.0,
    handlelength=2.2,
    columnspacing=1.5
)

fig.legend(
    handles=cluster_handles,
    title="Cluster color",
    loc="lower center",
    bbox_to_anchor=(0.75, 0.045),
    ncol=len(cluster_handles),
    frameon=True,
    fontsize=9.0,
    title_fontsize=10.0,
    handlelength=2.0,
    columnspacing=1.1
)

# -------------------------------------------------
# Keep most space for the graph while leaving room for legends
# -------------------------------------------------
fig.subplots_adjust(
    left=0.09,
    right=0.985,
    top=0.88,
    bottom=0.23
)

plt.show()

# %% [markdown]
# ### 9.8 EXTRA Elbow method comparison for all clustering backgrounds

# %%
fig, axes = plt.subplots(2, 3, figsize=(14, 8), sharex=False)

for ax, (feature_name, result) in zip(
    axes.ravel(),
    all_clustering_results.items()
):
    elbow_df = result["elbow_df"]

    ax.plot(
        elbow_df["k"],
        elbow_df["inertia"],
        marker="o",
        linewidth=2
    )

    ax.set_title(feature_name)
    ax.set_xlabel("Number of clusters, k")
    ax.set_ylabel("K-means inertia")
    ax.set_xticks(elbow_df["k"])
    ax.grid(True, linestyle="--", alpha=0.35)

# Hide unused subplot if there are fewer axes than panels
for ax in axes.ravel()[len(all_clustering_results):]:
    ax.axis("off")

fig.suptitle("Comparison of Elbow Method Across Clustering Feature Sets")
plt.tight_layout()
plt.show()
